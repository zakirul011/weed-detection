# %%
import os
import numpy as np
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler, Callback

from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, 
    roc_curve, confusion_matrix, classification_report, precision_recall_curve, average_precision_score
)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Directories
train_dir = '/kaggle/input/weed-detection-in-crop-fields/data/train'
test_dir = '/kaggle/input/weed-detection-in-crop-fields/data/test'

# Constants
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 50
LEARNING_RATE = 1e-5

# %%
# Data Generators
train_datagen = ImageDataGenerator(rescale=1.0/255, validation_split=0.2)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='binary', subset='training'
)

val_generator = train_datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='binary', subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='binary', shuffle=False
)
# Out:
# Found 833 images belonging to 2 classes.
# Found 207 images belonging to 2 classes.
# Found 260 images belonging to 2 classes.

# %%
# Feature Extraction with MobileNetV2
# base_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
# Feature Extraction with VGG16
# base_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
# Feature Extraction with ResNet50
# base_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
# Feature Extraction with InceptionV3
# base_model = tf.keras.applications.InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
# Feature Extraction with DenseNet121
base_model = tf.keras.applications.DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Feature Extraction with EfficientNetB0
# base_model = tf.keras.applications.EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
feature_extractor = Model(inputs=base_model.input, outputs=base_model.output)

def extract_features(generator, feature_extractor):
    features, labels = [], []
    for inputs, targets in generator:
        features.append(feature_extractor.predict(inputs))
        labels.append(targets)
        if len(features) >= len(generator):
            break
    return np.vstack(features), np.hstack(labels)

train_features, train_labels = extract_features(train_generator, feature_extractor)
val_features, val_labels = extract_features(val_generator, feature_extractor)
test_features, test_labels = extract_features(test_generator, feature_extractor)

train_features_flat = train_features.reshape(train_features.shape[0], -1)
val_features_flat = val_features.reshape(val_features.shape[0], -1)
test_features_flat = test_features.reshape(test_features.shape[0], -1)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733485312.802932   15577 service.cc:145] XLA service 0x789d8801b2d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733485312.802984   15577 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1733485312.802991   15577 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step
# I0000 00:00:1733485323.525059   15577 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step

# %%
# Custom callback to log learning rate and loss
class LearningRateLossLogger(Callback):
    def __init__(self):
        super().__init__()
        self.lrs = []
        self.losses = []

    def on_epoch_end(self, epoch, logs=None):
        self.lrs.append(self.model.optimizer.learning_rate.numpy())
        self.losses.append(logs.get('loss'))

# Learning rate scheduler function
def lr_scheduler(epoch, lr):
    return lr * 0.95  # Reduce learning rate by 5% each epoch

lr_logger = LearningRateLossLogger()
lr_scheduler_callback = LearningRateScheduler(lr_scheduler)

# %%
# custom callback for Precision, Recall, and F1-Score vs Epochs
class MetricsLogger(Callback):
    def __init__(self):
        super().__init__()
        self.precisions = []
        self.recalls = []
        self.f1_scores = []

    def on_epoch_end(self, epoch, logs=None):
        val_predictions = (self.model.predict(val_generator) > 0.5).astype(int).flatten()
        val_labels = val_generator.classes

        precision = precision_score(val_labels, val_predictions)
        recall = recall_score(val_labels, val_predictions)
        f1 = f1_score(val_labels, val_predictions)

        self.precisions.append(precision)
        self.recalls.append(recall)
        self.f1_scores.append(f1)

# Train model with the custom metrics logger
metrics_logger = MetricsLogger()

# %%
# Build and Fine-Tune End-to-End Classifier
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
output = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=output)
for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Initial training
history = model.fit(train_generator, validation_data=val_generator, epochs=EPOCHS)

# Fine-tune
for layer in base_model.layers:
    layer.trainable = True

model.compile(optimizer=Adam(LEARNING_RATE), loss='binary_crossentropy', metrics=['accuracy'])
fine_history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[lr_logger, metrics_logger, lr_scheduler_callback]
)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 40s 803ms/step - accuracy: 0.7703 - loss: 0.4714 - val_accuracy: 0.9662 - val_loss: 0.1461
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.9417 - loss: 0.2396 - val_accuracy: 0.9662 - val_loss: 0.1373
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.9383 - loss: 0.2040 - val_accuracy: 0.9662 - val_loss: 0.1550
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.9536 - loss: 0.1649 - val_accuracy: 0.9662 - val_loss: 0.1435
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9552 - loss: 0.1901 - val_accuracy: 0.9710 - val_loss: 0.1285
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.9682 - loss: 0.1526 - val_accuracy: 0.9710 - val_loss: 0.1238
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.9607 - loss: 0.1683 - val_accuracy: 0.9662 - val_loss: 0.1222
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.9593 - loss: 0.1622 - val_accuracy: 0.9710 - val_loss: 0.1246
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9610 - loss: 0.1417 - val_accuracy: 0.9710 - val_loss: 0.1384
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9609 - loss: 0.1305 - val_accuracy: 0.9710 - val_loss: 0.1200
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9659 - loss: 0.1677 - val_accuracy: 0.9710 - val_loss: 0.1226
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9683 - loss: 0.1250 - val_accuracy: 0.9710 - val_loss: 0.1151
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.9609 - loss: 0.1526 - val_accuracy: 0.9710 - val_loss: 0.1231
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9752 - loss: 0.0946 - val_accuracy: 0.9710 - val_loss: 0.1317
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9495 - loss: 0.1691 - val_accuracy: 0.9710 - val_loss: 0.1901
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9579 - loss: 0.1631 - val_accuracy: 0.9710 - val_loss: 0.1270
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9528 - loss: 0.1719 - val_accuracy: 0.9710 - val_loss: 0.1329
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9563 - loss: 0.1488 - val_accuracy: 0.9710 - val_loss: 0.1403
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9474 - loss: 0.1467 - val_accuracy: 0.9758 - val_loss: 0.1234
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9660 - loss: 0.1226 - val_accuracy: 0.9710 - val_loss: 0.1493
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.9707 - loss: 0.1060 - val_accuracy: 0.9710 - val_loss: 0.1251
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9638 - loss: 0.1206 - val_accuracy: 0.9662 - val_loss: 0.1279
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.9603 - loss: 0.1420 - val_accuracy: 0.9662 - val_loss: 0.1304
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.9618 - loss: 0.1369 - val_accuracy: 0.9614 - val_loss: 0.1421
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.9726 - loss: 0.0980 - val_accuracy: 0.9662 - val_loss: 0.1321
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9710 - loss: 0.1110 - val_accuracy: 0.9662 - val_loss: 0.1534
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.9584 - loss: 0.1485 - val_accuracy: 0.9710 - val_loss: 0.1645
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9646 - loss: 0.1070 - val_accuracy: 0.9662 - val_loss: 0.1625
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.9678 - loss: 0.1021 - val_accuracy: 0.9662 - val_loss: 0.1485
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9681 - loss: 0.1122 - val_accuracy: 0.9710 - val_loss: 0.1625
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.9662 - loss: 0.1036 - val_accuracy: 0.9710 - val_loss: 0.1300
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9610 - loss: 0.1208 - val_accuracy: 0.9614 - val_loss: 0.1255
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.9621 - loss: 0.1027 - val_accuracy: 0.9662 - val_loss: 0.1403
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.9708 - loss: 0.1084 - val_accuracy: 0.9662 - val_loss: 0.1428
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.9646 - loss: 0.1263 - val_accuracy: 0.9662 - val_loss: 0.1411
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.9637 - loss: 0.1044 - val_accuracy: 0.9710 - val_loss: 0.1326
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9671 - loss: 0.1130 - val_accuracy: 0.9662 - val_loss: 0.1663
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9831 - loss: 0.0838 - val_accuracy: 0.9614 - val_loss: 0.1359
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.9734 - loss: 0.1015 - val_accuracy: 0.9662 - val_loss: 0.1508
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9582 - loss: 0.1223 - val_accuracy: 0.9710 - val_loss: 0.1457
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9688 - loss: 0.1131 - val_accuracy: 0.9662 - val_loss: 0.1353
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9799 - loss: 0.0868 - val_accuracy: 0.9614 - val_loss: 0.1481
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9710 - loss: 0.1063 - val_accuracy: 0.9662 - val_loss: 0.1527
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9614 - loss: 0.1153 - val_accuracy: 0.9662 - val_loss: 0.1416
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.9651 - loss: 0.1034 - val_accuracy: 0.9565 - val_loss: 0.1603
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.9642 - loss: 0.1159 - val_accuracy: 0.9710 - val_loss: 0.1312
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.9674 - loss: 0.1096 - val_accuracy: 0.9662 - val_loss: 0.1395
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.9717 - loss: 0.0922 - val_accuracy: 0.9662 - val_loss: 0.1244
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.9628 - loss: 0.1065 - val_accuracy: 0.9710 - val_loss: 0.1182
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.9680 - loss: 0.1062 - val_accuracy: 0.9662 - val_loss: 0.1294
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step  - accuracy: 0.7554 - loss
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 227s 4s/step - accuracy: 0.7570 - loss: 0.7292 - val_accuracy: 0.9614 - val_loss: 0.1428 - learning_rate: 9.5000e-06
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step ep - accuracy: 0.9007 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - accuracy: 0.9006 - loss: 0.2419 - val_accuracy: 0.9614 - val_loss: 0.1649 - learning_rate: 9.0250e-06
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step ep - accuracy: 0.9354 - loss
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 351ms/step - accuracy: 0.9351 - loss: 0.2170 - val_accuracy: 0.9662 - val_loss: 0.1827 - learning_rate: 8.5737e-06
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step ep - accuracy: 0.9343 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 353ms/step - accuracy: 0.9342 - loss: 0.2110 - val_accuracy: 0.9662 - val_loss: 0.1953 - learning_rate: 8.1451e-06
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step ep - accuracy: 0.9268 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 354ms/step - accuracy: 0.9267 - loss: 0.2093 - val_accuracy: 0.9662 - val_loss: 0.2082 - learning_rate: 7.7378e-06
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step ep - accuracy: 0.9386 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 352ms/step - accuracy: 0.9389 - loss: 0.1808 - val_accuracy: 0.9662 - val_loss: 0.2131 - learning_rate: 7.3509e-06
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step ep - accuracy: 0.9406 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 350ms/step - accuracy: 0.9407 - loss: 0.1842 - val_accuracy: 0.9662 - val_loss: 0.2115 - learning_rate: 6.9834e-06
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step ep - accuracy: 0.9538 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 347ms/step - accuracy: 0.9537 - loss: 0.1483 - val_accuracy: 0.9662 - val_loss: 0.2182 - learning_rate: 6.6342e-06
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step ep - accuracy: 0.9662 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 348ms/step - accuracy: 0.9662 - loss: 0.1093 - val_accuracy: 0.9662 - val_loss: 0.2178 - learning_rate: 6.3025e-06
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step ep - accuracy: 0.9768 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 347ms/step - accuracy: 0.9765 - loss: 0.0733 - val_accuracy: 0.9662 - val_loss: 0.2153 - learning_rate: 5.9874e-06
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step ep - accuracy: 0.9786 - lo
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 351ms/step - accuracy: 0.9785 - loss: 0.0638 - val_accuracy: 0.9710 - val_loss: 0.2200 - learning_rate: 5.6880e-06
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/stepep - accuracy: 0.9653
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 351ms/step - accuracy: 0.9652 - loss: 0.0969 - val_accuracy: 0.9710 - val_loss: 0.2289 - learning_rate: 5.4036e-06
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/stepep - accuracy: 0.9633
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 354ms/step - accuracy: 0.9633 - loss: 0.1234 - val_accuracy: 0.9710 - val_loss: 0.2304 - learning_rate: 5.1334e-06
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step ep - accuracy: 0.9506 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 347ms/step - accuracy: 0.9514 - loss: 0.0979 - val_accuracy: 0.9710 - val_loss: 0.2391 - learning_rate: 4.8767e-06
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step ep - accuracy: 0.9529 - lo
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 345ms/step - accuracy: 0.9532 - loss: 0.1016 - val_accuracy: 0.9710 - val_loss: 0.2421 - learning_rate: 4.6329e-06
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step ep - accuracy: 0.9777 - loss
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 343ms/step - accuracy: 0.9776 - loss: 0.0591 - val_accuracy: 0.9710 - val_loss: 0.2466 - learning_rate: 4.4013e-06
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step ep - accuracy: 0.9723 - loss
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 344ms/step - accuracy: 0.9725 - loss: 0.0733 - val_accuracy: 0.9710 - val_loss: 0.2467 - learning_rate: 4.1812e-06
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step ep - accuracy: 0.9753 - loss
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 350ms/step - accuracy: 0.9755 - loss: 0.0740 - val_accuracy: 0.9710 - val_loss: 0.2485 - learning_rate: 3.9721e-06
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step ep - accuracy: 0.9791 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 346ms/step - accuracy: 0.9791 - loss: 0.0682 - val_accuracy: 0.9710 - val_loss: 0.2468 - learning_rate: 3.7735e-06
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step ep - accuracy: 0.9774 - los
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 346ms/step - accuracy: 0.9775 - loss: 0.0562 - val_accuracy: 0.9710 - val_loss: 0.2439 - learning_rate: 3.5849e-06
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step ep - accuracy: 0.9686 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 350ms/step - accuracy: 0.9688 - loss: 0.0587 - val_accuracy: 0.9710 - val_loss: 0.2405 - learning_rate: 3.4056e-06
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step ep - accuracy: 0.9666 - loss
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 345ms/step - accuracy: 0.9667 - loss: 0.0809 - val_accuracy: 0.9710 - val_loss: 0.2401 - learning_rate: 3.2353e-06
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step ep - accuracy: 0.9694 - lo
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 348ms/step - accuracy: 0.9697 - loss: 0.0774 - val_accuracy: 0.9710 - val_loss: 0.2416 - learning_rate: 3.0736e-06
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step ep - accuracy: 0.9823 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 352ms/step - accuracy: 0.9823 - loss: 0.0618 - val_accuracy: 0.9710 - val_loss: 0.2411 - learning_rate: 2.9199e-06
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step ep - accuracy: 0.9800 - loss
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 352ms/step - accuracy: 0.9800 - loss: 0.0573 - val_accuracy: 0.9710 - val_loss: 0.2436 - learning_rate: 2.7739e-06
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step ep - accuracy: 0.9897 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 346ms/step - accuracy: 0.9892 - loss: 0.0340 - val_accuracy: 0.9710 - val_loss: 0.2417 - learning_rate: 2.6352e-06
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step ep - accuracy: 0.9820 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 353ms/step - accuracy: 0.9819 - loss: 0.0387 - val_accuracy: 0.9710 - val_loss: 0.2403 - learning_rate: 2.5034e-06
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step ep - accuracy: 0.9873 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 345ms/step - accuracy: 0.9871 - loss: 0.0375 - val_accuracy: 0.9710 - val_loss: 0.2431 - learning_rate: 2.3783e-06
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step ep - accuracy: 0.9860 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 347ms/step - accuracy: 0.9858 - loss: 0.0396 - val_accuracy: 0.9710 - val_loss: 0.2457 - learning_rate: 2.2594e-06
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step ep - accuracy: 0.9894 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 350ms/step - accuracy: 0.9893 - loss: 0.0300 - val_accuracy: 0.9710 - val_loss: 0.2445 - learning_rate: 2.1464e-06
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/stepep - accuracy: 0.9758
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 352ms/step - accuracy: 0.9758 - loss: 0.0754 - val_accuracy: 0.9710 - val_loss: 0.2444 - learning_rate: 2.0391e-06
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step ep - accuracy: 0.9921 - loss
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 345ms/step - accuracy: 0.9919 - loss: 0.0313 - val_accuracy: 0.9710 - val_loss: 0.2463 - learning_rate: 1.9371e-06
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step ep - accuracy: 0.9815 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 350ms/step - accuracy: 0.9814 - loss: 0.0508 - val_accuracy: 0.9710 - val_loss: 0.2458 - learning_rate: 1.8403e-06
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step ep - accuracy: 0.9718 - loss
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 344ms/step - accuracy: 0.9720 - loss: 0.0752 - val_accuracy: 0.9710 - val_loss: 0.2450 - learning_rate: 1.7482e-06
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step ep - accuracy: 0.9791 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 348ms/step - accuracy: 0.9790 - loss: 0.0417 - val_accuracy: 0.9710 - val_loss: 0.2456 - learning_rate: 1.6608e-06
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step ep - accuracy: 0.9875 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 356ms/step - accuracy: 0.9875 - loss: 0.0368 - val_accuracy: 0.9710 - val_loss: 0.2446 - learning_rate: 1.5778e-06
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step ep - accuracy: 0.9947 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 346ms/step - accuracy: 0.9947 - loss: 0.0240 - val_accuracy: 0.9710 - val_loss: 0.2432 - learning_rate: 1.4989e-06
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step ep - accuracy: 0.9820 - lo
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 343ms/step - accuracy: 0.9824 - loss: 0.0393 - val_accuracy: 0.9710 - val_loss: 0.2471 - learning_rate: 1.4240e-06
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/stepep - accuracy: 0.9721
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 354ms/step - accuracy: 0.9719 - loss: 0.0651 - val_accuracy: 0.9710 - val_loss: 0.2452 - learning_rate: 1.3528e-06
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step ep - accuracy: 0.9461 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 354ms/step - accuracy: 0.9473 - loss: 0.1154 - val_accuracy: 0.9710 - val_loss: 0.2450 - learning_rate: 1.2851e-06
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step ep - accuracy: 0.9890 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 348ms/step - accuracy: 0.9889 - loss: 0.0389 - val_accuracy: 0.9710 - val_loss: 0.2463 - learning_rate: 1.2209e-06
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step ep - accuracy: 0.9790 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 348ms/step - accuracy: 0.9790 - loss: 0.0590 - val_accuracy: 0.9710 - val_loss: 0.2485 - learning_rate: 1.1598e-06
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step ep - accuracy: 0.9795 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - accuracy: 0.9796 - loss: 0.0418 - val_accuracy: 0.9710 - val_loss: 0.2470 - learning_rate: 1.1018e-06
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step ep - accuracy: 0.9908 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 344ms/step - accuracy: 0.9906 - loss: 0.0279 - val_accuracy: 0.9710 - val_loss: 0.2471 - learning_rate: 1.0467e-06
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step ep - accuracy: 0.9875 - lo
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 347ms/step - accuracy: 0.9874 - loss: 0.0483 - val_accuracy: 0.9710 - val_loss: 0.2486 - learning_rate: 9.9440e-07
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step ep - accuracy: 0.9811 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - accuracy: 0.9812 - loss: 0.0464 - val_accuracy: 0.9710 - val_loss: 0.2482 - learning_rate: 9.4468e-07
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step ep - accuracy: 0.9827 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 347ms/step - accuracy: 0.9828 - loss: 0.0391 - val_accuracy: 0.9710 - val_loss: 0.2491 - learning_rate: 8.9745e-07
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step ep - accuracy: 0.9798 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 347ms/step - accuracy: 0.9798 - loss: 0.0422 - val_accuracy: 0.9710 - val_loss: 0.2515 - learning_rate: 8.5258e-07
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/stepep - accuracy: 0.9865
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 356ms/step - accuracy: 0.9866 - loss: 0.0334 - val_accuracy: 0.9710 - val_loss: 0.2515 - learning_rate: 8.0995e-07
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/stepep - accuracy: 0.9928
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 351ms/step - accuracy: 0.9927 - loss: 0.0409 - val_accuracy: 0.9710 - val_loss: 0.2532 - learning_rate: 7.6945e-07

# %%
# Classifiers
classifiers = {
    "SVM": SVC(probability=True),
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(),
    "Decision Tree": DecisionTreeClassifier()
}

for name, clf in classifiers.items():
    clf.fit(train_features_flat, train_labels)

# %%
def evaluate(clf, X, y_true, is_keras_model=False):
    if is_keras_model:
        y_pred = (clf.predict(X) > 0.5).astype(int).flatten()
        y_proba = clf.predict(X).flatten()
    else:
        y_pred = clf.predict(X)
        y_proba = clf.predict_proba(X)[:, 1] if hasattr(clf, "predict_proba") else None

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_proba) if y_proba is not None else None

    print("\nClassification Report:")
    print(classification_report(y_true, y_pred))

    return accuracy, precision, recall, f1, auc

# %%
# Evaluate classifiers
true_labels = test_generator.classes
for name, clf in classifiers.items():
    print(f"\n{name} Performance:")
    metrics = evaluate(clf, test_features_flat, true_labels)
    print(f"Accuracy: {metrics[0]:.4f}, Precision: {metrics[1]:.4f}, Recall: {metrics[2]:.4f}, "
          f"F1: {metrics[3]:.4f}, AUC: {metrics[4]:.4f}")

# Evaluate Model
metrics = evaluate(model, test_generator, true_labels, is_keras_model=True)
print("\nModel Performance:")
print(f"Accuracy: {metrics[0]:.4f}, Precision: {metrics[1]:.4f}, Recall: {metrics[2]:.4f}, "
      f"F1: {metrics[3]:.4f}, AUC: {metrics[4]:.4f}")
# Out:
# SVM Performance:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       127
#            1       0.97      0.98      0.98       133
#
#     accuracy                           0.98       260
#    macro avg       0.98      0.98      0.98       260
# weighted avg       0.98      0.98      0.98       260
#
# Accuracy: 0.9769, Precision: 0.9704, Recall: 0.9850, F1: 0.9776, AUC: 0.9815
#
# Logistic Regression Performance:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       127
#            1       0.98      0.98      0.98       133
#
#     accuracy                           0.98       260
#    macro avg       0.98      0.98      0.98       260
# weighted avg       0.98      0.98      0.98       260
#
# Accuracy: 0.9769, Precision: 0.9774, Recall: 0.9774, F1: 0.9774, AUC: 0.9843
#
# Random Forest Performance:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96       127
#            1       0.95      0.98      0.97       133
#
#     accuracy                           0.97       260
#    macro avg       0.97      0.96      0.97       260
# weighted avg       0.97      0.97      0.97       260
#
# Accuracy: 0.9654, Precision: 0.9493, Recall: 0.9850, F1: 0.9668, AUC: 0.9848
#
# Decision Tree Performance:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       127
#            1       0.91      0.89      0.90       133
#
#     accuracy                           0.90       260
#    macro avg       0.90      0.90      0.90       260
# weighted avg       0.90      0.90      0.90       260
#
# Accuracy: 0.9000, Precision: 0.9084, Recall: 0.8947, F1: 0.9015, AUC: 0.9001
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 612ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       127
#            1       0.98      0.98      0.98       133
#
#     accuracy                           0.98       260
#    macro avg       0.98      0.98      0.98       260
# weighted avg       0.98      0.98      0.98       260
#
#
# Model Performance:
# Accuracy: 0.9808, Precision: 0.9776, Recall: 0.9850, F1: 0.9813, AUC: 0.9800

# %%
# Visualization

# Plot Training vs Validation Accuracy and Loss
def plot_training(history, title):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{title} - Loss')
    plt.legend()
    plt.show()

# ROC Curve
def plot_auc_roc(y_true, y_proba, title="AUC-ROC Curve"):
    fpr, tpr, _ = roc_curve(y_true, y_proba)
    auc_score = roc_auc_score(y_true, y_proba)
    
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'AUC = {auc_score:.4f}', color='blue')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Guess')
    plt.title(title)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.grid()
    plt.show()

# Confusion Matrix
def plot_confusion_matrix(y_true, y_pred, title="Confusion Matrix"):
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=test_generator.class_indices.keys(), 
                yticklabels=test_generator.class_indices.keys())
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

# Function to plot Precision-Recall Curve
def plot_precision_recall(y_true, y_proba, title="Precision vs Recall Curve"):
    precision, recall, _ = precision_recall_curve(y_true, y_proba)
    avg_precision = average_precision_score(y_true, y_proba)
    
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, label=f'AP = {avg_precision:.4f}', color='purple')
    plt.title(title)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.grid()
    plt.show()

# Plot Learning Rate vs Loss
def plot_LR(title="Learning Rate vs Loss"):
    plt.figure(figsize=(8, 6))
    plt.plot(lr_logger.lrs, lr_logger.losses, marker='o', color='purple')
    plt.title(title)
    plt.xlabel("Learning Rate")
    plt.ylabel("Loss")
    plt.xscale('log')
    plt.grid()
    plt.show()

# Plot Precision, Recall, and F1-Score vs Epochs
def plot_metrices_epochs(title="Precision, Recall, and F1-Score vs Epochs"):
    plt.figure(figsize=(8, 6))
    epochs_range = range(1, EPOCHS + 1)
    plt.plot(epochs_range, metrics_logger.precisions, label='Precision', color='blue')
    plt.plot(epochs_range, metrics_logger.recalls, label='Recall', color='green')
    plt.plot(epochs_range, metrics_logger.f1_scores, label='F1-Score', color='red')
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Score")
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Training vs Validation Accuracy and Loss
plot_training(history, "Initial Training")
plot_training(fine_history, "Fine-Tuning")

# Generate and visualize results
y_proba = model.predict(test_generator).flatten()
y_pred = (y_proba > 0.5).astype(int)

# ROC Curve and AUC
plot_auc_roc(true_labels, y_proba)

# Confusion Matrix
plot_confusion_matrix(true_labels, y_pred)

# Precision-Recall Curve
plot_precision_recall(true_labels, y_proba)

# Learning Rate vs Loss
plot_LR()

# Precision, Recall, and F1-Score vs Epochs
plot_metrices_epochs()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step
