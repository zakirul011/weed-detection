# %%
import os
import numpy as np
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler, Callback

from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, 
    roc_curve, confusion_matrix, classification_report, precision_recall_curve, average_precision_score
)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Directories
train_dir = '/kaggle/input/weed-detection-in-crop-fields/data/train'
test_dir = '/kaggle/input/weed-detection-in-crop-fields/data/test'

# Constants
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 50
LEARNING_RATE = 1e-5

# %%
# Data Generators
train_datagen = ImageDataGenerator(rescale=1.0/255, validation_split=0.2)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='binary', subset='training'
)

val_generator = train_datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='binary', subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='binary', shuffle=False
)
# Out:
# Found 833 images belonging to 2 classes.
# Found 207 images belonging to 2 classes.
# Found 260 images belonging to 2 classes.

# %%
# Feature Extraction with MobileNetV2
# base_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
# Feature Extraction with VGG16
base_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
# Feature Extraction with VGG19
# base_model = tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
feature_extractor = Model(inputs=base_model.input, outputs=base_model.output)

def extract_features(generator, feature_extractor):
    features, labels = [], []
    for inputs, targets in generator:
        features.append(feature_extractor.predict(inputs))
        labels.append(targets)
        if len(features) >= len(generator):
            break
    return np.vstack(features), np.hstack(labels)

train_features, train_labels = extract_features(train_generator, feature_extractor)
val_features, val_labels = extract_features(val_generator, feature_extractor)
test_features, test_labels = extract_features(test_generator, feature_extractor)

train_features_flat = train_features.reshape(train_features.shape[0], -1)
val_features_flat = val_features.reshape(val_features.shape[0], -1)
test_features_flat = test_features.reshape(test_features.shape[0], -1)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733479819.937753    5247 service.cc:145] XLA service 0x7d3110005260 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733479819.937809    5247 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1733479819.937813    5247 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# I0000 00:00:1733479832.092291    5247 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
# Custom callback to log learning rate and loss
class LearningRateLossLogger(Callback):
    def __init__(self):
        super().__init__()
        self.lrs = []
        self.losses = []

    def on_epoch_end(self, epoch, logs=None):
        self.lrs.append(self.model.optimizer.learning_rate.numpy())
        self.losses.append(logs.get('loss'))

# Learning rate scheduler function
def lr_scheduler(epoch, lr):
    return lr * 0.95  # Reduce learning rate by 5% each epoch

lr_logger = LearningRateLossLogger()
lr_scheduler_callback = LearningRateScheduler(lr_scheduler)

# %%
# custom callback for Precision, Recall, and F1-Score vs Epochs
class MetricsLogger(Callback):
    def __init__(self):
        super().__init__()
        self.precisions = []
        self.recalls = []
        self.f1_scores = []

    def on_epoch_end(self, epoch, logs=None):
        val_predictions = (self.model.predict(val_generator) > 0.5).astype(int).flatten()
        val_labels = val_generator.classes

        precision = precision_score(val_labels, val_predictions)
        recall = recall_score(val_labels, val_predictions)
        f1 = f1_score(val_labels, val_predictions)

        self.precisions.append(precision)
        self.recalls.append(recall)
        self.f1_scores.append(f1)

# Train model with the custom metrics logger
metrics_logger = MetricsLogger()

# %%
# Build and Fine-Tune End-to-End Classifier
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
output = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=output)
for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Initial training
history = model.fit(train_generator, validation_data=val_generator, epochs=EPOCHS)

# Fine-tune
for layer in base_model.layers:
    layer.trainable = True

model.compile(optimizer=Adam(LEARNING_RATE), loss='binary_crossentropy', metrics=['accuracy'])
fine_history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[lr_logger, metrics_logger, lr_scheduler_callback]
)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 263ms/step - accuracy: 0.6954 - loss: 0.5732 - val_accuracy: 0.9275 - val_loss: 0.2261
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.9140 - loss: 0.2633 - val_accuracy: 0.9372 - val_loss: 0.1779
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9109 - loss: 0.2383 - val_accuracy: 0.9517 - val_loss: 0.1668
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9324 - loss: 0.2223 - val_accuracy: 0.9324 - val_loss: 0.1665
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.9334 - loss: 0.2166 - val_accuracy: 0.9469 - val_loss: 0.1621
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - accuracy: 0.9107 - loss: 0.2457 - val_accuracy: 0.9565 - val_loss: 0.1579
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - accuracy: 0.9301 - loss: 0.2113 - val_accuracy: 0.9614 - val_loss: 0.1511
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.9426 - loss: 0.1803 - val_accuracy: 0.9517 - val_loss: 0.1616
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.9378 - loss: 0.2275 - val_accuracy: 0.9565 - val_loss: 0.1536
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.9308 - loss: 0.2019 - val_accuracy: 0.9565 - val_loss: 0.1562
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.9176 - loss: 0.2576 - val_accuracy: 0.9565 - val_loss: 0.1563
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9434 - loss: 0.1770 - val_accuracy: 0.9662 - val_loss: 0.1514
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.9600 - loss: 0.1401 - val_accuracy: 0.9662 - val_loss: 0.1490
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9570 - loss: 0.1618 - val_accuracy: 0.9662 - val_loss: 0.1462
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.9471 - loss: 0.1932 - val_accuracy: 0.9614 - val_loss: 0.1492
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9555 - loss: 0.1699 - val_accuracy: 0.9614 - val_loss: 0.1535
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9448 - loss: 0.1708 - val_accuracy: 0.9614 - val_loss: 0.1572
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.9415 - loss: 0.1935 - val_accuracy: 0.9469 - val_loss: 0.2026
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9212 - loss: 0.2684 - val_accuracy: 0.9614 - val_loss: 0.1456
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9366 - loss: 0.2111 - val_accuracy: 0.9662 - val_loss: 0.1412
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.9569 - loss: 0.1729 - val_accuracy: 0.9614 - val_loss: 0.1421
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.9417 - loss: 0.1770 - val_accuracy: 0.9710 - val_loss: 0.1396
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.9393 - loss: 0.2110 - val_accuracy: 0.9614 - val_loss: 0.1445
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9631 - loss: 0.1465 - val_accuracy: 0.9662 - val_loss: 0.1389
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.9405 - loss: 0.1935 - val_accuracy: 0.9662 - val_loss: 0.1414
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9521 - loss: 0.1551 - val_accuracy: 0.9614 - val_loss: 0.1447
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9680 - loss: 0.1374 - val_accuracy: 0.9565 - val_loss: 0.1617
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9542 - loss: 0.1859 - val_accuracy: 0.9710 - val_loss: 0.1403
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9405 - loss: 0.2084 - val_accuracy: 0.9710 - val_loss: 0.1400
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9410 - loss: 0.2020 - val_accuracy: 0.9614 - val_loss: 0.1449
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.9561 - loss: 0.1712 - val_accuracy: 0.9420 - val_loss: 0.2470
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9527 - loss: 0.1987 - val_accuracy: 0.9614 - val_loss: 0.1545
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.9359 - loss: 0.1890 - val_accuracy: 0.9662 - val_loss: 0.1436
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9532 - loss: 0.1551 - val_accuracy: 0.9710 - val_loss: 0.1387
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9442 - loss: 0.1927 - val_accuracy: 0.9662 - val_loss: 0.1377
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9636 - loss: 0.1388 - val_accuracy: 0.9662 - val_loss: 0.1411
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9434 - loss: 0.2096 - val_accuracy: 0.9710 - val_loss: 0.1379
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9559 - loss: 0.1481 - val_accuracy: 0.9662 - val_loss: 0.1443
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.9658 - loss: 0.1446 - val_accuracy: 0.9710 - val_loss: 0.1370
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9450 - loss: 0.1693 - val_accuracy: 0.9710 - val_loss: 0.1437
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9487 - loss: 0.1771 - val_accuracy: 0.9662 - val_loss: 0.1475
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9528 - loss: 0.1772 - val_accuracy: 0.9614 - val_loss: 0.1449
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9265 - loss: 0.2786 - val_accuracy: 0.9614 - val_loss: 0.1523
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9456 - loss: 0.1864 - val_accuracy: 0.9662 - val_loss: 0.1376
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.9642 - loss: 0.1259 - val_accuracy: 0.9662 - val_loss: 0.1367
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9636 - loss: 0.1373 - val_accuracy: 0.9662 - val_loss: 0.1397
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9569 - loss: 0.1791 - val_accuracy: 0.9662 - val_loss: 0.1377
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.9470 - loss: 0.1632 - val_accuracy: 0.9662 - val_loss: 0.1422
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9570 - loss: 0.1507 - val_accuracy: 0.9662 - val_loss: 0.1413
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9555 - loss: 0.1622 - val_accuracy: 0.9662 - val_loss: 0.1423
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 168ms/stepep - accuracy: 0.9336
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 51s 774ms/step - accuracy: 0.9339 - loss: 0.2028 - val_accuracy: 0.9662 - val_loss: 0.1872 - learning_rate: 9.5000e-06
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/stepep - accuracy: 0.9527
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 481ms/step - accuracy: 0.9530 - loss: 0.1796 - val_accuracy: 0.9758 - val_loss: 0.1540 - learning_rate: 9.0250e-06
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9598
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 484ms/step - accuracy: 0.9600 - loss: 0.1456 - val_accuracy: 0.9710 - val_loss: 0.1529 - learning_rate: 8.5737e-06
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9668
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 483ms/step - accuracy: 0.9669 - loss: 0.1038 - val_accuracy: 0.9758 - val_loss: 0.1461 - learning_rate: 8.1451e-06
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9670
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 483ms/step - accuracy: 0.9671 - loss: 0.1061 - val_accuracy: 0.9758 - val_loss: 0.1661 - learning_rate: 7.7378e-06
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9809
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 503ms/step - accuracy: 0.9809 - loss: 0.0702 - val_accuracy: 0.9758 - val_loss: 0.1804 - learning_rate: 7.3509e-06
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9814
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 485ms/step - accuracy: 0.9811 - loss: 0.0569 - val_accuracy: 0.9758 - val_loss: 0.1697 - learning_rate: 6.9834e-06
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9727
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 485ms/step - accuracy: 0.9729 - loss: 0.0798 - val_accuracy: 0.9662 - val_loss: 0.1860 - learning_rate: 6.6342e-06
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9764
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 486ms/step - accuracy: 0.9764 - loss: 0.0656 - val_accuracy: 0.9710 - val_loss: 0.1493 - learning_rate: 6.3025e-06
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9796
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 489ms/step - accuracy: 0.9796 - loss: 0.0677 - val_accuracy: 0.9710 - val_loss: 0.1870 - learning_rate: 5.9874e-06
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9845
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 486ms/step - accuracy: 0.9841 - loss: 0.0453 - val_accuracy: 0.9758 - val_loss: 0.2013 - learning_rate: 5.6880e-06
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9885
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 484ms/step - accuracy: 0.9884 - loss: 0.0348 - val_accuracy: 0.9710 - val_loss: 0.1932 - learning_rate: 5.4036e-06
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9725
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 486ms/step - accuracy: 0.9727 - loss: 0.0596 - val_accuracy: 0.9758 - val_loss: 0.1959 - learning_rate: 5.1334e-06
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9797
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 487ms/step - accuracy: 0.9797 - loss: 0.0548 - val_accuracy: 0.9710 - val_loss: 0.2028 - learning_rate: 4.8767e-06
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9870
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 491ms/step - accuracy: 0.9868 - loss: 0.0319 - val_accuracy: 0.9710 - val_loss: 0.2467 - learning_rate: 4.6329e-06
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9883
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 488ms/step - accuracy: 0.9883 - loss: 0.0318 - val_accuracy: 0.9662 - val_loss: 0.2611 - learning_rate: 4.4013e-06
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9857
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 486ms/step - accuracy: 0.9855 - loss: 0.0331 - val_accuracy: 0.9758 - val_loss: 0.2182 - learning_rate: 4.1812e-06
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9937
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 484ms/step - accuracy: 0.9935 - loss: 0.0242 - val_accuracy: 0.9710 - val_loss: 0.3178 - learning_rate: 3.9721e-06
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9876
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 488ms/step - accuracy: 0.9876 - loss: 0.0349 - val_accuracy: 0.9758 - val_loss: 0.2559 - learning_rate: 3.7735e-06
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9874
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 485ms/step - accuracy: 0.9874 - loss: 0.0369 - val_accuracy: 0.9758 - val_loss: 0.2746 - learning_rate: 3.5849e-06
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9903
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 486ms/step - accuracy: 0.9903 - loss: 0.0242 - val_accuracy: 0.9758 - val_loss: 0.2586 - learning_rate: 3.4056e-06
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9929
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 485ms/step - accuracy: 0.9928 - loss: 0.0197 - val_accuracy: 0.9662 - val_loss: 0.2951 - learning_rate: 3.2353e-06
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/stepep - accuracy: 0.9890
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 487ms/step - accuracy: 0.9890 - loss: 0.0272 - val_accuracy: 0.9710 - val_loss: 0.2836 - learning_rate: 3.0736e-06
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9936
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 487ms/step - accuracy: 0.9934 - loss: 0.0220 - val_accuracy: 0.9662 - val_loss: 0.2986 - learning_rate: 2.9199e-06
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9814
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 484ms/step - accuracy: 0.9816 - loss: 0.0391 - val_accuracy: 0.9758 - val_loss: 0.2822 - learning_rate: 2.7739e-06
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/stepep - accuracy: 0.9863
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 487ms/step - accuracy: 0.9863 - loss: 0.0340 - val_accuracy: 0.9758 - val_loss: 0.2664 - learning_rate: 2.6352e-06
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9947
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 487ms/step - accuracy: 0.9946 - loss: 0.0150 - val_accuracy: 0.9758 - val_loss: 0.2727 - learning_rate: 2.5034e-06
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/stepep - accuracy: 0.9922
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 484ms/step - accuracy: 0.9922 - loss: 0.0218 - val_accuracy: 0.9710 - val_loss: 0.2707 - learning_rate: 2.3783e-06
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9957
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 485ms/step - accuracy: 0.9955 - loss: 0.0129 - val_accuracy: 0.9710 - val_loss: 0.2903 - learning_rate: 2.2594e-06
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9890
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 484ms/step - accuracy: 0.9889 - loss: 0.0251 - val_accuracy: 0.9710 - val_loss: 0.2910 - learning_rate: 2.1464e-06
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9992
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 486ms/step - accuracy: 0.9991 - loss: 0.0135 - val_accuracy: 0.9710 - val_loss: 0.2908 - learning_rate: 2.0391e-06
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9959
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 486ms/step - accuracy: 0.9958 - loss: 0.0127 - val_accuracy: 0.9662 - val_loss: 0.2927 - learning_rate: 1.9371e-06
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9840
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 485ms/step - accuracy: 0.9841 - loss: 0.0257 - val_accuracy: 0.9662 - val_loss: 0.2767 - learning_rate: 1.8403e-06
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9946
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 483ms/step - accuracy: 0.9945 - loss: 0.0136 - val_accuracy: 0.9662 - val_loss: 0.2903 - learning_rate: 1.7482e-06
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9909
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 485ms/step - accuracy: 0.9909 - loss: 0.0166 - val_accuracy: 0.9710 - val_loss: 0.3070 - learning_rate: 1.6608e-06
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9950
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 487ms/step - accuracy: 0.9950 - loss: 0.0151 - val_accuracy: 0.9662 - val_loss: 0.2847 - learning_rate: 1.5778e-06
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/stepep - accuracy: 0.9909
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 488ms/step - accuracy: 0.9910 - loss: 0.0178 - val_accuracy: 0.9710 - val_loss: 0.3083 - learning_rate: 1.4989e-06
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9878
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 484ms/step - accuracy: 0.9878 - loss: 0.0315 - val_accuracy: 0.9662 - val_loss: 0.2782 - learning_rate: 1.4240e-06
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9929
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 488ms/step - accuracy: 0.9931 - loss: 0.0186 - val_accuracy: 0.9662 - val_loss: 0.2945 - learning_rate: 1.3528e-06
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9977
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 489ms/step - accuracy: 0.9975 - loss: 0.0117 - val_accuracy: 0.9662 - val_loss: 0.2908 - learning_rate: 1.2851e-06
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9977
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 484ms/step - accuracy: 0.9976 - loss: 0.0117 - val_accuracy: 0.9710 - val_loss: 0.3047 - learning_rate: 1.2209e-06
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/stepep - accuracy: 0.9933
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 486ms/step - accuracy: 0.9933 - loss: 0.0138 - val_accuracy: 0.9710 - val_loss: 0.2916 - learning_rate: 1.1598e-06
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9975
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 485ms/step - accuracy: 0.9973 - loss: 0.0119 - val_accuracy: 0.9710 - val_loss: 0.2953 - learning_rate: 1.1018e-06
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9999
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 486ms/step - accuracy: 0.9999 - loss: 0.0055 - val_accuracy: 0.9662 - val_loss: 0.3202 - learning_rate: 1.0467e-06
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9919
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 488ms/step - accuracy: 0.9920 - loss: 0.0192 - val_accuracy: 0.9662 - val_loss: 0.2819 - learning_rate: 9.9440e-07
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/stepep - accuracy: 0.9974
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 482ms/step - accuracy: 0.9970 - loss: 0.0118 - val_accuracy: 0.9710 - val_loss: 0.3013 - learning_rate: 9.4468e-07
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 1.0000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 483ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.9710 - val_loss: 0.3019 - learning_rate: 8.9745e-07
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9898
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 486ms/step - accuracy: 0.9899 - loss: 0.0229 - val_accuracy: 0.9710 - val_loss: 0.2974 - learning_rate: 8.5258e-07
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9972
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 487ms/step - accuracy: 0.9971 - loss: 0.0102 - val_accuracy: 0.9662 - val_loss: 0.3025 - learning_rate: 8.0995e-07
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/stepep - accuracy: 0.9965
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 488ms/step - accuracy: 0.9964 - loss: 0.0136 - val_accuracy: 0.9614 - val_loss: 0.3685 - learning_rate: 7.6945e-07

# %%
# Classifiers
classifiers = {
    "SVM": SVC(probability=True),
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(),
    "Decision Tree": DecisionTreeClassifier()
}

for name, clf in classifiers.items():
    clf.fit(train_features_flat, train_labels)

# %%
def evaluate(clf, X, y_true, is_keras_model=False):
    if is_keras_model:
        y_pred = (clf.predict(X) > 0.5).astype(int).flatten()
        y_proba = clf.predict(X).flatten()
    else:
        y_pred = clf.predict(X)
        y_proba = clf.predict_proba(X)[:, 1] if hasattr(clf, "predict_proba") else None

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_proba) if y_proba is not None else None

    print("\nClassification Report:")
    print(classification_report(y_true, y_pred))

    return accuracy, precision, recall, f1, auc

# %%
# Evaluate classifiers
true_labels = test_generator.classes
for name, clf in classifiers.items():
    print(f"\n{name} Performance:")
    metrics = evaluate(clf, test_features_flat, true_labels)
    print(f"Accuracy: {metrics[0]:.4f}, Precision: {metrics[1]:.4f}, Recall: {metrics[2]:.4f}, "
          f"F1: {metrics[3]:.4f}, AUC: {metrics[4]:.4f}")

# Evaluate Model
metrics = evaluate(model, test_generator, true_labels, is_keras_model=True)
print("\nModel Performance:")
print(f"Accuracy: {metrics[0]:.4f}, Precision: {metrics[1]:.4f}, Recall: {metrics[2]:.4f}, "
      f"F1: {metrics[3]:.4f}, AUC: {metrics[4]:.4f}")
# Out:
# SVM Performance:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       127
#            1       0.96      0.98      0.97       133
#
#     accuracy                           0.97       260
#    macro avg       0.97      0.97      0.97       260
# weighted avg       0.97      0.97      0.97       260
#
# Accuracy: 0.9692, Precision: 0.9562, Recall: 0.9850, F1: 0.9704, AUC: 0.9855
#
# Logistic Regression Performance:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96       127
#            1       0.97      0.96      0.97       133
#
#     accuracy                           0.97       260
#    macro avg       0.97      0.97      0.97       260
# weighted avg       0.97      0.97      0.97       260
#
# Accuracy: 0.9654, Precision: 0.9697, Recall: 0.9624, F1: 0.9660, AUC: 0.9784
#
# Random Forest Performance:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96       127
#            1       0.95      0.98      0.96       133
#
#     accuracy                           0.96       260
#    macro avg       0.96      0.96      0.96       260
# weighted avg       0.96      0.96      0.96       260
#
# Accuracy: 0.9615, Precision: 0.9489, Recall: 0.9774, F1: 0.9630, AUC: 0.9863
#
# Decision Tree Performance:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       127
#            1       0.94      0.92      0.93       133
#
#     accuracy                           0.93       260
#    macro avg       0.93      0.93      0.93       260
# weighted avg       0.93      0.93      0.93       260
#
# Accuracy: 0.9269, Precision: 0.9385, Recall: 0.9173, F1: 0.9278, AUC: 0.9272
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       127
#            1       0.98      0.98      0.98       133
#
#     accuracy                           0.98       260
#    macro avg       0.98      0.98      0.98       260
# weighted avg       0.98      0.98      0.98       260
#
#
# Model Performance:
# Accuracy: 0.9808, Precision: 0.9776, Recall: 0.9850, F1: 0.9813, AUC: 0.9818

# %%
# Visualization

# Plot Training vs Validation Accuracy and Loss
def plot_training(history, title):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{title} - Loss')
    plt.legend()
    plt.show()

# ROC Curve
def plot_auc_roc(y_true, y_proba, title="AUC-ROC Curve"):
    fpr, tpr, _ = roc_curve(y_true, y_proba)
    auc_score = roc_auc_score(y_true, y_proba)
    
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'AUC = {auc_score:.4f}', color='blue')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Guess')
    plt.title(title)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.grid()
    plt.show()

# Confusion Matrix
def plot_confusion_matrix(y_true, y_pred, title="Confusion Matrix"):
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=test_generator.class_indices.keys(), 
                yticklabels=test_generator.class_indices.keys())
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

# Function to plot Precision-Recall Curve
def plot_precision_recall(y_true, y_proba, title="Precision vs Recall Curve"):
    precision, recall, _ = precision_recall_curve(y_true, y_proba)
    avg_precision = average_precision_score(y_true, y_proba)
    
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, label=f'AP = {avg_precision:.4f}', color='purple')
    plt.title(title)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.grid()
    plt.show()

# Plot Learning Rate vs Loss
def plot_LR(title="Learning Rate vs Loss"):
    plt.figure(figsize=(8, 6))
    plt.plot(lr_logger.lrs, lr_logger.losses, marker='o', color='purple')
    plt.title(title)
    plt.xlabel("Learning Rate")
    plt.ylabel("Loss")
    plt.xscale('log')
    plt.grid()
    plt.show()

# Plot Precision, Recall, and F1-Score vs Epochs
def plot_metrices_epochs(title="Precision, Recall, and F1-Score vs Epochs"):
    plt.figure(figsize=(8, 6))
    epochs_range = range(1, EPOCHS + 1)
    plt.plot(epochs_range, metrics_logger.precisions, label='Precision', color='blue')
    plt.plot(epochs_range, metrics_logger.recalls, label='Recall', color='green')
    plt.plot(epochs_range, metrics_logger.f1_scores, label='F1-Score', color='red')
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Score")
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Training vs Validation Accuracy and Loss
plot_training(history, "Initial Training")
plot_training(fine_history, "Fine-Tuning")

# Generate and visualize results
y_proba = model.predict(test_generator).flatten()
y_pred = (y_proba > 0.5).astype(int)

# ROC Curve and AUC
plot_auc_roc(true_labels, y_proba)

# Confusion Matrix
plot_confusion_matrix(true_labels, y_pred)

# Precision-Recall Curve
plot_precision_recall(true_labels, y_proba)

# Learning Rate vs Loss
plot_LR()

# Precision, Recall, and F1-Score vs Epochs
plot_metrices_epochs()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step
