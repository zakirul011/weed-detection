# %%
import os
import numpy as np
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler, Callback

from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, 
    roc_curve, confusion_matrix, classification_report, precision_recall_curve, average_precision_score
)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Directories
train_dir = '/kaggle/input/weed-detection-in-crop-fields/data/train'
test_dir = '/kaggle/input/weed-detection-in-crop-fields/data/test'

# Constants
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 50
LEARNING_RATE = 1e-5

# %%
# Data Generators
train_datagen = ImageDataGenerator(rescale=1.0/255, validation_split=0.2)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='binary', subset='training'
)

val_generator = train_datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='binary', subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='binary', shuffle=False
)
# Out:
# Found 833 images belonging to 2 classes.
# Found 207 images belonging to 2 classes.
# Found 260 images belonging to 2 classes.

# %%
# Feature Extraction with MobileNetV2
# base_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
# Feature Extraction with VGG16
# base_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
# Feature Extraction with ResNet50
# base_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
# Feature Extraction with InceptionV3
base_model = tf.keras.applications.InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
feature_extractor = Model(inputs=base_model.input, outputs=base_model.output)

def extract_features(generator, feature_extractor):
    features, labels = [], []
    for inputs, targets in generator:
        features.append(feature_extractor.predict(inputs))
        labels.append(targets)
        if len(features) >= len(generator):
            break
    return np.vstack(features), np.hstack(labels)

train_features, train_labels = extract_features(train_generator, feature_extractor)
val_features, val_labels = extract_features(val_generator, feature_extractor)
test_features, test_labels = extract_features(test_generator, feature_extractor)

train_features_flat = train_features.reshape(train_features.shape[0], -1)
val_features_flat = val_features.reshape(val_features.shape[0], -1)
test_features_flat = test_features.reshape(test_features.shape[0], -1)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733482804.301767   10968 service.cc:145] XLA service 0x7aa158003ac0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733482804.301810   10968 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1733482804.301814   10968 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# I0000 00:00:1733482811.245761   10968 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
# Custom callback to log learning rate and loss
class LearningRateLossLogger(Callback):
    def __init__(self):
        super().__init__()
        self.lrs = []
        self.losses = []

    def on_epoch_end(self, epoch, logs=None):
        self.lrs.append(self.model.optimizer.learning_rate.numpy())
        self.losses.append(logs.get('loss'))

# Learning rate scheduler function
def lr_scheduler(epoch, lr):
    return lr * 0.95  # Reduce learning rate by 5% each epoch

lr_logger = LearningRateLossLogger()
lr_scheduler_callback = LearningRateScheduler(lr_scheduler)

# %%
# custom callback for Precision, Recall, and F1-Score vs Epochs
class MetricsLogger(Callback):
    def __init__(self):
        super().__init__()
        self.precisions = []
        self.recalls = []
        self.f1_scores = []

    def on_epoch_end(self, epoch, logs=None):
        val_predictions = (self.model.predict(val_generator) > 0.5).astype(int).flatten()
        val_labels = val_generator.classes

        precision = precision_score(val_labels, val_predictions)
        recall = recall_score(val_labels, val_predictions)
        f1 = f1_score(val_labels, val_predictions)

        self.precisions.append(precision)
        self.recalls.append(recall)
        self.f1_scores.append(f1)

# Train model with the custom metrics logger
metrics_logger = MetricsLogger()

# %%
# Build and Fine-Tune End-to-End Classifier
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
output = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=output)
for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Initial training
history = model.fit(train_generator, validation_data=val_generator, epochs=EPOCHS)

# Fine-tune
for layer in base_model.layers:
    layer.trainable = True

model.compile(optimizer=Adam(LEARNING_RATE), loss='binary_crossentropy', metrics=['accuracy'])
fine_history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[lr_logger, metrics_logger, lr_scheduler_callback]
)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 26s 545ms/step - accuracy: 0.7999 - loss: 0.4183 - val_accuracy: 0.9565 - val_loss: 0.1525
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.9538 - loss: 0.1844 - val_accuracy: 0.9662 - val_loss: 0.1349
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.9477 - loss: 0.2014 - val_accuracy: 0.9614 - val_loss: 0.1310
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.9583 - loss: 0.1602 - val_accuracy: 0.9614 - val_loss: 0.1255
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 0.9628 - loss: 0.1300 - val_accuracy: 0.9662 - val_loss: 0.1383
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.9619 - loss: 0.1245 - val_accuracy: 0.9565 - val_loss: 0.1380
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.9744 - loss: 0.0989 - val_accuracy: 0.9517 - val_loss: 0.1500
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.9709 - loss: 0.1019 - val_accuracy: 0.9614 - val_loss: 0.1354
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.9648 - loss: 0.0950 - val_accuracy: 0.9710 - val_loss: 0.1500
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.9682 - loss: 0.1144 - val_accuracy: 0.9565 - val_loss: 0.1431
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9802 - loss: 0.0721 - val_accuracy: 0.9710 - val_loss: 0.1476
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.9761 - loss: 0.0853 - val_accuracy: 0.9565 - val_loss: 0.1443
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9706 - loss: 0.0954 - val_accuracy: 0.9275 - val_loss: 0.1920
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.9625 - loss: 0.0929 - val_accuracy: 0.9614 - val_loss: 0.1352
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9642 - loss: 0.0951 - val_accuracy: 0.9614 - val_loss: 0.1550
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.9707 - loss: 0.0883 - val_accuracy: 0.9082 - val_loss: 0.2655
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9590 - loss: 0.0923 - val_accuracy: 0.9517 - val_loss: 0.1535
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.9729 - loss: 0.0799 - val_accuracy: 0.9614 - val_loss: 0.1487
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9683 - loss: 0.0732 - val_accuracy: 0.9517 - val_loss: 0.1508
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9793 - loss: 0.0540 - val_accuracy: 0.9614 - val_loss: 0.1755
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.9767 - loss: 0.0668 - val_accuracy: 0.9565 - val_loss: 0.1675
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.9518 - loss: 0.1138 - val_accuracy: 0.9517 - val_loss: 0.1830
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9694 - loss: 0.1060 - val_accuracy: 0.9614 - val_loss: 0.1933
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9685 - loss: 0.0705 - val_accuracy: 0.9517 - val_loss: 0.1800
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.9762 - loss: 0.0712 - val_accuracy: 0.9565 - val_loss: 0.1653
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9805 - loss: 0.0437 - val_accuracy: 0.9662 - val_loss: 0.1704
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.9780 - loss: 0.0516 - val_accuracy: 0.9565 - val_loss: 0.1640
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.9753 - loss: 0.0713 - val_accuracy: 0.9614 - val_loss: 0.1865
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.9720 - loss: 0.0579 - val_accuracy: 0.9565 - val_loss: 0.1762
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9777 - loss: 0.0550 - val_accuracy: 0.9565 - val_loss: 0.1564
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9860 - loss: 0.0431 - val_accuracy: 0.9565 - val_loss: 0.1663
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.9835 - loss: 0.0473 - val_accuracy: 0.9614 - val_loss: 0.1945
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.9779 - loss: 0.0549 - val_accuracy: 0.9710 - val_loss: 0.1674
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.9790 - loss: 0.0426 - val_accuracy: 0.9565 - val_loss: 0.1804
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.9784 - loss: 0.0455 - val_accuracy: 0.9517 - val_loss: 0.1749
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.9752 - loss: 0.0738 - val_accuracy: 0.9517 - val_loss: 0.1690
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9895 - loss: 0.0402 - val_accuracy: 0.9565 - val_loss: 0.1786
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.9872 - loss: 0.0372 - val_accuracy: 0.9662 - val_loss: 0.1828
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9830 - loss: 0.0371 - val_accuracy: 0.9662 - val_loss: 0.2198
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.9644 - loss: 0.0845 - val_accuracy: 0.9710 - val_loss: 0.1809
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.9878 - loss: 0.0313 - val_accuracy: 0.9710 - val_loss: 0.1687
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.9925 - loss: 0.0323 - val_accuracy: 0.9517 - val_loss: 0.1764
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.9899 - loss: 0.0242 - val_accuracy: 0.9565 - val_loss: 0.1843
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.9792 - loss: 0.0476 - val_accuracy: 0.9614 - val_loss: 0.1891
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.9811 - loss: 0.0519 - val_accuracy: 0.9662 - val_loss: 0.1744
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.9933 - loss: 0.0282 - val_accuracy: 0.9710 - val_loss: 0.1822
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9933 - loss: 0.0267 - val_accuracy: 0.9662 - val_loss: 0.2086
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.9842 - loss: 0.0331 - val_accuracy: 0.9565 - val_loss: 0.1614
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.9858 - loss: 0.0322 - val_accuracy: 0.9662 - val_loss: 0.1857
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.9944 - loss: 0.0240 - val_accuracy: 0.9614 - val_loss: 0.2015
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 800ms/step- accuracy: 0.6361 - los
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.6378 - loss: 1.2276 - val_accuracy: 0.9710 - val_loss: 0.1704 - learning_rate: 9.5000e-06
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step ep - accuracy: 0.8549 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 284ms/step - accuracy: 0.8554 - loss: 0.4248 - val_accuracy: 0.9517 - val_loss: 0.1753 - learning_rate: 9.0250e-06
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step ep - accuracy: 0.9302 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 286ms/step - accuracy: 0.9297 - loss: 0.2700 - val_accuracy: 0.9372 - val_loss: 0.1818 - learning_rate: 8.5737e-06
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step ep - accuracy: 0.9357 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - accuracy: 0.9359 - loss: 0.1549 - val_accuracy: 0.9565 - val_loss: 0.1663 - learning_rate: 8.1451e-06
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step ep - accuracy: 0.9443 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 285ms/step - accuracy: 0.9448 - loss: 0.1507 - val_accuracy: 0.9565 - val_loss: 0.1683 - learning_rate: 7.7378e-06
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step ep - accuracy: 0.9568 - loss
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 277ms/step - accuracy: 0.9570 - loss: 0.1596 - val_accuracy: 0.9614 - val_loss: 0.1730 - learning_rate: 7.3509e-06
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step ep - accuracy: 0.9683 - loss:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 277ms/step - accuracy: 0.9682 - loss: 0.1146 - val_accuracy: 0.9565 - val_loss: 0.1478 - learning_rate: 6.9834e-06
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step ep - accuracy: 0.9659 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 275ms/step - accuracy: 0.9658 - loss: 0.0828 - val_accuracy: 0.9565 - val_loss: 0.1483 - learning_rate: 6.6342e-06
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step ep - accuracy: 0.9718 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - accuracy: 0.9718 - loss: 0.0800 - val_accuracy: 0.9614 - val_loss: 0.1581 - learning_rate: 6.3025e-06
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step ep - accuracy: 0.9646 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 277ms/step - accuracy: 0.9648 - loss: 0.0731 - val_accuracy: 0.9565 - val_loss: 0.1679 - learning_rate: 5.9874e-06
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step ep - accuracy: 0.9854 - los
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.9853 - loss: 0.0415 - val_accuracy: 0.9662 - val_loss: 0.1642 - learning_rate: 5.6880e-06
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step ep - accuracy: 0.9793 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.9791 - loss: 0.0514 - val_accuracy: 0.9710 - val_loss: 0.1715 - learning_rate: 5.4036e-06
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step ep - accuracy: 0.9794 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - accuracy: 0.9793 - loss: 0.0547 - val_accuracy: 0.9710 - val_loss: 0.1794 - learning_rate: 5.1334e-06
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step ep - accuracy: 0.9756 - los
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 278ms/step - accuracy: 0.9758 - loss: 0.0572 - val_accuracy: 0.9710 - val_loss: 0.1879 - learning_rate: 4.8767e-06
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step ep - accuracy: 0.9836 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.9835 - loss: 0.0431 - val_accuracy: 0.9710 - val_loss: 0.1956 - learning_rate: 4.6329e-06
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step ep - accuracy: 0.9822 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 283ms/step - accuracy: 0.9824 - loss: 0.0446 - val_accuracy: 0.9710 - val_loss: 0.2017 - learning_rate: 4.4013e-06
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step ep - accuracy: 0.9818 - loss
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.9820 - loss: 0.0390 - val_accuracy: 0.9710 - val_loss: 0.2035 - learning_rate: 4.1812e-06
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step ep - accuracy: 0.9775 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 278ms/step - accuracy: 0.9775 - loss: 0.0490 - val_accuracy: 0.9662 - val_loss: 0.2048 - learning_rate: 3.9721e-06
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step ep - accuracy: 0.9741 - loss
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 275ms/step - accuracy: 0.9742 - loss: 0.0530 - val_accuracy: 0.9662 - val_loss: 0.2052 - learning_rate: 3.7735e-06
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step ep - accuracy: 0.9906 - loss:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 276ms/step - accuracy: 0.9906 - loss: 0.0283 - val_accuracy: 0.9710 - val_loss: 0.2043 - learning_rate: 3.5849e-06
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step ep - accuracy: 0.9867 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.9868 - loss: 0.0321 - val_accuracy: 0.9710 - val_loss: 0.2046 - learning_rate: 3.4056e-06
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step ep - accuracy: 0.9842 - los
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 280ms/step - accuracy: 0.9842 - loss: 0.0354 - val_accuracy: 0.9662 - val_loss: 0.2064 - learning_rate: 3.2353e-06
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/stepep - accuracy: 0.9890
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 285ms/step - accuracy: 0.9890 - loss: 0.0248 - val_accuracy: 0.9710 - val_loss: 0.2046 - learning_rate: 3.0736e-06
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/stepep - accuracy: 0.9883 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 284ms/step - accuracy: 0.9881 - loss: 0.0259 - val_accuracy: 0.9710 - val_loss: 0.2070 - learning_rate: 2.9199e-06
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step ep - accuracy: 0.9912 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.9913 - loss: 0.0223 - val_accuracy: 0.9710 - val_loss: 0.2122 - learning_rate: 2.7739e-06
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step ep - accuracy: 0.9841 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 280ms/step - accuracy: 0.9842 - loss: 0.0465 - val_accuracy: 0.9710 - val_loss: 0.2136 - learning_rate: 2.6352e-06
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step ep - accuracy: 0.9903 - loss:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 286ms/step - accuracy: 0.9902 - loss: 0.0375 - val_accuracy: 0.9710 - val_loss: 0.2168 - learning_rate: 2.5034e-06
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step ep - accuracy: 0.9953 - los
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.9953 - loss: 0.0149 - val_accuracy: 0.9710 - val_loss: 0.2191 - learning_rate: 2.3783e-06
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step ep - accuracy: 0.9977 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 287ms/step - accuracy: 0.9975 - loss: 0.0140 - val_accuracy: 0.9710 - val_loss: 0.2166 - learning_rate: 2.2594e-06
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step ep - accuracy: 0.9821 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 285ms/step - accuracy: 0.9824 - loss: 0.0734 - val_accuracy: 0.9710 - val_loss: 0.2178 - learning_rate: 2.1464e-06
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step ep - accuracy: 0.9889 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - accuracy: 0.9889 - loss: 0.0310 - val_accuracy: 0.9710 - val_loss: 0.2192 - learning_rate: 2.0391e-06
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step ep - accuracy: 0.9908 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.9908 - loss: 0.0320 - val_accuracy: 0.9662 - val_loss: 0.2226 - learning_rate: 1.9371e-06
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step ep - accuracy: 0.9874 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 283ms/step - accuracy: 0.9875 - loss: 0.0307 - val_accuracy: 0.9710 - val_loss: 0.2212 - learning_rate: 1.8403e-06
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step ep - accuracy: 0.9799 - los
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - accuracy: 0.9801 - loss: 0.0431 - val_accuracy: 0.9710 - val_loss: 0.2247 - learning_rate: 1.7482e-06
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step ep - accuracy: 0.9963 - los
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.9963 - loss: 0.0236 - val_accuracy: 0.9710 - val_loss: 0.2252 - learning_rate: 1.6608e-06
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step ep - accuracy: 0.9931 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 280ms/step - accuracy: 0.9930 - loss: 0.0210 - val_accuracy: 0.9710 - val_loss: 0.2247 - learning_rate: 1.5778e-06
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step ep - accuracy: 0.9905 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 278ms/step - accuracy: 0.9905 - loss: 0.0212 - val_accuracy: 0.9710 - val_loss: 0.2253 - learning_rate: 1.4989e-06
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step ep - accuracy: 0.9973 - loss:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 285ms/step - accuracy: 0.9972 - loss: 0.0116 - val_accuracy: 0.9710 - val_loss: 0.2249 - learning_rate: 1.4240e-06
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step ep - accuracy: 0.9962 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.9961 - loss: 0.0140 - val_accuracy: 0.9662 - val_loss: 0.2279 - learning_rate: 1.3528e-06
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step ep - accuracy: 0.9782 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - accuracy: 0.9786 - loss: 0.0370 - val_accuracy: 0.9710 - val_loss: 0.2273 - learning_rate: 1.2851e-06
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step ep - accuracy: 0.9933 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 284ms/step - accuracy: 0.9932 - loss: 0.0266 - val_accuracy: 0.9662 - val_loss: 0.2280 - learning_rate: 1.2209e-06
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step ep - accuracy: 0.9962 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.9962 - loss: 0.0115 - val_accuracy: 0.9710 - val_loss: 0.2264 - learning_rate: 1.1598e-06
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step ep - accuracy: 0.9905 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.9904 - loss: 0.0269 - val_accuracy: 0.9710 - val_loss: 0.2255 - learning_rate: 1.1018e-06
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step ep - accuracy: 0.9942 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - accuracy: 0.9941 - loss: 0.0262 - val_accuracy: 0.9710 - val_loss: 0.2286 - learning_rate: 1.0467e-06
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step ep - accuracy: 0.9923 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.9923 - loss: 0.0198 - val_accuracy: 0.9662 - val_loss: 0.2266 - learning_rate: 9.9440e-07
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step ep - accuracy: 0.9971 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 283ms/step - accuracy: 0.9970 - loss: 0.0111 - val_accuracy: 0.9710 - val_loss: 0.2277 - learning_rate: 9.4468e-07
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step ep - accuracy: 0.9885 - loss
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 289ms/step - accuracy: 0.9884 - loss: 0.0366 - val_accuracy: 0.9710 - val_loss: 0.2295 - learning_rate: 8.9745e-07
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step ep - accuracy: 0.9969 - l
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - accuracy: 0.9969 - loss: 0.0261 - val_accuracy: 0.9662 - val_loss: 0.2274 - learning_rate: 8.5258e-07
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step ep - accuracy: 0.9980 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 280ms/step - accuracy: 0.9980 - loss: 0.0092 - val_accuracy: 0.9710 - val_loss: 0.2238 - learning_rate: 8.0995e-07
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step ep - accuracy: 0.9946 -
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.9946 - loss: 0.0146 - val_accuracy: 0.9710 - val_loss: 0.2253 - learning_rate: 7.6945e-07

# %%
# Classifiers
classifiers = {
    "SVM": SVC(probability=True),
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(),
    "Decision Tree": DecisionTreeClassifier()
}

for name, clf in classifiers.items():
    clf.fit(train_features_flat, train_labels)

# %%
def evaluate(clf, X, y_true, is_keras_model=False):
    if is_keras_model:
        y_pred = (clf.predict(X) > 0.5).astype(int).flatten()
        y_proba = clf.predict(X).flatten()
    else:
        y_pred = clf.predict(X)
        y_proba = clf.predict_proba(X)[:, 1] if hasattr(clf, "predict_proba") else None

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_proba) if y_proba is not None else None

    print("\nClassification Report:")
    print(classification_report(y_true, y_pred))

    return accuracy, precision, recall, f1, auc

# %%
# Evaluate classifiers
true_labels = test_generator.classes
for name, clf in classifiers.items():
    print(f"\n{name} Performance:")
    metrics = evaluate(clf, test_features_flat, true_labels)
    print(f"Accuracy: {metrics[0]:.4f}, Precision: {metrics[1]:.4f}, Recall: {metrics[2]:.4f}, "
          f"F1: {metrics[3]:.4f}, AUC: {metrics[4]:.4f}")

# Evaluate Model
metrics = evaluate(model, test_generator, true_labels, is_keras_model=True)
print("\nModel Performance:")
print(f"Accuracy: {metrics[0]:.4f}, Precision: {metrics[1]:.4f}, Recall: {metrics[2]:.4f}, "
      f"F1: {metrics[3]:.4f}, AUC: {metrics[4]:.4f}")
# Out:
# SVM Performance:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       127
#            1       0.98      0.98      0.98       133
#
#     accuracy                           0.98       260
#    macro avg       0.98      0.98      0.98       260
# weighted avg       0.98      0.98      0.98       260
#
# Accuracy: 0.9808, Precision: 0.9776, Recall: 0.9850, F1: 0.9813, AUC: 0.9785
#
# Logistic Regression Performance:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       127
#            1       0.97      0.97      0.97       133
#
#     accuracy                           0.97       260
#    macro avg       0.97      0.97      0.97       260
# weighted avg       0.97      0.97      0.97       260
#
# Accuracy: 0.9692, Precision: 0.9699, Recall: 0.9699, F1: 0.9699, AUC: 0.9806
#
# Random Forest Performance:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96       127
#            1       0.96      0.98      0.97       133
#
#     accuracy                           0.97       260
#    macro avg       0.97      0.97      0.97       260
# weighted avg       0.97      0.97      0.97       260
#
# Accuracy: 0.9654, Precision: 0.9559, Recall: 0.9774, F1: 0.9665, AUC: 0.9815
#
# Decision Tree Performance:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90       127
#            1       0.89      0.94      0.91       133
#
#     accuracy                           0.91       260
#    macro avg       0.91      0.91      0.91       260
# weighted avg       0.91      0.91      0.91       260
#
# Accuracy: 0.9077, Precision: 0.8865, Recall: 0.9398, F1: 0.9124, AUC: 0.9069
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 381ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       127
#            1       0.97      0.97      0.97       133
#
#     accuracy                           0.97       260
#    macro avg       0.97      0.97      0.97       260
# weighted avg       0.97      0.97      0.97       260
#
#
# Model Performance:
# Accuracy: 0.9692, Precision: 0.9699, Recall: 0.9699, F1: 0.9699, AUC: 0.9797

# %%
# Visualization

# Plot Training vs Validation Accuracy and Loss
def plot_training(history, title):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{title} - Loss')
    plt.legend()
    plt.show()

# ROC Curve
def plot_auc_roc(y_true, y_proba, title="AUC-ROC Curve"):
    fpr, tpr, _ = roc_curve(y_true, y_proba)
    auc_score = roc_auc_score(y_true, y_proba)
    
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'AUC = {auc_score:.4f}', color='blue')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Guess')
    plt.title(title)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.grid()
    plt.show()

# Confusion Matrix
def plot_confusion_matrix(y_true, y_pred, title="Confusion Matrix"):
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=test_generator.class_indices.keys(), 
                yticklabels=test_generator.class_indices.keys())
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

# Function to plot Precision-Recall Curve
def plot_precision_recall(y_true, y_proba, title="Precision vs Recall Curve"):
    precision, recall, _ = precision_recall_curve(y_true, y_proba)
    avg_precision = average_precision_score(y_true, y_proba)
    
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, label=f'AP = {avg_precision:.4f}', color='purple')
    plt.title(title)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.grid()
    plt.show()

# Plot Learning Rate vs Loss
def plot_LR(title="Learning Rate vs Loss"):
    plt.figure(figsize=(8, 6))
    plt.plot(lr_logger.lrs, lr_logger.losses, marker='o', color='purple')
    plt.title(title)
    plt.xlabel("Learning Rate")
    plt.ylabel("Loss")
    plt.xscale('log')
    plt.grid()
    plt.show()

# Plot Precision, Recall, and F1-Score vs Epochs
def plot_metrices_epochs(title="Precision, Recall, and F1-Score vs Epochs"):
    plt.figure(figsize=(8, 6))
    epochs_range = range(1, EPOCHS + 1)
    plt.plot(epochs_range, metrics_logger.precisions, label='Precision', color='blue')
    plt.plot(epochs_range, metrics_logger.recalls, label='Recall', color='green')
    plt.plot(epochs_range, metrics_logger.f1_scores, label='F1-Score', color='red')
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Score")
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Training vs Validation Accuracy and Loss
plot_training(history, "Initial Training")
plot_training(fine_history, "Fine-Tuning")

# Generate and visualize results
y_proba = model.predict(test_generator).flatten()
y_pred = (y_proba > 0.5).astype(int)

# ROC Curve and AUC
plot_auc_roc(true_labels, y_proba)

# Confusion Matrix
plot_confusion_matrix(true_labels, y_pred)

# Precision-Recall Curve
plot_precision_recall(true_labels, y_proba)

# Learning Rate vs Loss
plot_LR()

# Precision, Recall, and F1-Score vs Epochs
plot_metrices_epochs()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step
